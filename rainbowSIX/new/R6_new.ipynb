# %% [markdown]
# <a href="https://colab.research.google.com/github/Georgia-MAX-holic/Footprints/blob/main/PJ/rainbowSIX/new/R6_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  ![화면 캡처 2023-02-12 193737.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # 기본
#
# - install category_encoders
# - google.colab import drive
# - import pandas as pd
# - plt
# - seaborn
# - df_operators
# - df_objectives
#
# - 데이터셋 :
#
#  https://www.ubisoft.com/en-ca/game/rainbow-six/siege/news-updates/2fQ8bGRr6SlS7B4u5jpVt1/introduction-to-the-data-peek-velvet-shell-statistics

# %%
# !pip install category_encoders

from google.colab import drive
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

drive.mount('/content/gdrive', force_remount=True)
pathA = '/content/gdrive/MyDrive/cpding/S5_operators.csv'
pathB = '/content/gdrive/MyDrive/cpding/S5_objectives.csv'
df_operators = pd.read_csv(pathA , sep=";")
df_objectives = pd.read_csv(pathB , sep=";")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: category_encoders in /usr/local/lib/python3.8/dist-packages (2.6.0)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.8/dist-packages (from category_encoders) (0.12.2)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.8/dist-packages (from category_encoders) (1.21.6)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.8/dist-packages (from category_encoders) (1.0.2)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.8/dist-packages (from category_encoders) (0.5.3)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.8/dist-packages (from category_encoders) (1.3.5)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from category_encoders) (1.7.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.5->category_encoders) (2022.7.1)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from patsy>=0.5.1->category_encoders) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.20.0->category_encoders) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.20.0->category_encoders) (1.2.0)
# Mounted at /content/gdrive

# %%
df_operators.head()
# Out:
#   platform    dateid skillrank      role       operator primaryweapon  \
# 0       PC  20170210    Bronze  Attacker   BOPE-CAPITAO          M249
# 1       PC  20170210    Bronze  Attacker   BOPE-CAPITAO          M249
# 2       PC  20170210    Bronze  Attacker   BOPE-CAPITAO      PARA-308
# 3       PC  20170210    Bronze  Attacker   BOPE-CAPITAO      PARA-308
# 4       PC  20170210    Bronze  Attacker  G.E.O.-JACKAL           C7E
#
#   secondaryweapon secondarygadget  nbwins  nbkills  nbdeaths  nbpicks
# 0           PRB92        CLAYMORE       6        6         6        8
# 1           PRB92    STUN GRENADE       4        2         6        8
# 2           PRB92        CLAYMORE      37       40        49       70
# 3           PRB92    STUN GRENADE      17       24        31       41
# 4          ITA12S   BREACH CHARGE      74      123       127      174

# %%
df_objectives.head()
# Out:
#   platform    dateid    gamemode mapname              objectivelocation  \
# 0       PC  20170210  PvP . BOMB    BANK  EXECUTIVE LOUNGE / CEO OFFICE
# 1       PC  20170210  PvP . BOMB    BANK  EXECUTIVE LOUNGE / CEO OFFICE
# 2       PC  20170210  PvP . BOMB    BANK  EXECUTIVE LOUNGE / CEO OFFICE
# 3       PC  20170210  PvP . BOMB    BANK  EXECUTIVE LOUNGE / CEO OFFICE
# 4       PC  20170210  PvP . BOMB    BANK  EXECUTIVE LOUNGE / CEO OFFICE
#
#   skillrank      role       operator  nbwins  nbkills  nbdeaths  nbpicks
# 0    Bronze  Attacker  G.E.O.-JACKAL       0        0         1        1
# 1    Bronze  Attacker  GIGN-MONTAGNE       1        0         2        3
# 2    Bronze  Attacker        GSG9-IQ       0        0         1        1
# 3    Bronze  Attacker      JTF2-BUCK       0        0         1        1
# 4    Bronze  Attacker   SAS-THATCHER       0        0         1        1

# %% [markdown]
# # 기본 전처리

# %% [markdown]
# 앞으로 있을 분석들을 위하여 KDA와 승률을 계산한다

# %%
df_operators["k/d_ratio"]= df_operators["nbkills"]/df_operators["nbdeaths"]
df_operators["win_ratio"]= df_operators["nbwins"]/df_operators["nbpicks"]

df_objectives["k/d_ratio"]= df_objectives["nbkills"]/df_objectives["nbdeaths"]
df_objectives["win_ratio"]= df_objectives["nbwins"]/df_objectives["nbpicks"]

# %% [markdown]
# 0데스 , 매치중 한번도 안죽은 플레이어는 KDA가 집계되지 않아 데이터로 이용할 수 없다. 그렇기에 제거

# %%
INDEX_oper   = df_operators[df_operators["nbdeaths"]==0].index
df_operators = df_operators.drop(INDEX_oper)

INDEX_obj   = df_objectives[df_objectives["nbdeaths"]==0].index
df_objectives = df_objectives.drop(INDEX_obj)

print(df_operators.isnull().sum())
print(df_objectives.isnull().sum())
# Out:
# platform           0
# dateid             0
# skillrank          0
# role               0
# operator           0
# primaryweapon      0
# secondaryweapon    0
# secondarygadget    0
# nbwins             0
# nbkills            0
# nbdeaths           0
# nbpicks            0
# k/d_ratio          0
# win_ratio          0
# dtype: int64
# platform             0
# dateid               0
# gamemode             0
# mapname              0
# objectivelocation    0
# skillrank            0
# role                 0
# operator             0
# nbwins               0
# nbkills              0
# nbdeaths             0
# nbpicks              0
# k/d_ratio            0
# win_ratio            0
# dtype: int64

# %% [markdown]
# # 공/수 오퍼레이터들 데이터 시각화
#
# -  결측치 없음
#
# - 우선 나온 데이터들을 픽률, 승률 기준으로 시각화를 시켜보자, 값이 높을수록 현재 쓰기 좋은 오퍼레이터라고 볼 수 있다 .
#
# - 이를 위해서는 필요한 데이터 ( operator , win_ratio, nbpicks)만 남기고 전부 잘라내야하고  operator 를 기준으로 승률과 픽률을 평균해서 정렬해야한다 .

# %% [markdown]
# ## Code

# %%
df_ATK = df_operators[df_operators["role"]=="Attacker"][["operator","win_ratio","k/d_ratio","nbpicks"]]
df_DEF = df_operators[df_operators["role"]=="Defender"][["operator","win_ratio","k/d_ratio","nbpicks"]]

# %% [markdown]
# - 전체 데이터로 시각화를 한번 해봤는데 오퍼레이터 숫자가 너무 많아 보기가 힘들었다.
#
# - 공격 , 수비 오퍼레이터로 분리해서 시각화

# %%
df_graph_ATK=df_ATK.groupby(['operator'], as_index=False).mean()
df_graph_DEF=df_DEF.groupby(['operator'], as_index=False).mean()

# %% [markdown]
# ## 그래프
#
# -  데이터 그대로의 픽률과 승률을 시각화 한것

# %%
sns.relplot(x="nbpicks", y="win_ratio", hue="operator", style= "operator" , data=df_ATK)
plt.show()

# %%
sns.relplot(x="nbpicks", y="win_ratio", hue="operator", style= "operator" , data=df_DEF)
plt.show()

# %% [markdown]
# 데이터들은 평균 승률 0.5로 모여있음 , 랭크가 올라갈수록 승리하기 어렵기 때문

# %% [markdown]
# win/ picks 그래프

# %%
sns.relplot(x="nbpicks", y="win_ratio", hue="operator", style= "operator" , data=df_graph_ATK).fig.set_size_inches(10,5)
plt.show()

# %%
sns.relplot(x="nbpicks", y="win_ratio", hue="operator", style= "operator" , data=df_graph_DEF).fig.set_size_inches(10,5)
plt.show()
 # 승률 그래프

# %% [markdown]
# - 공격
#    - 가장 승률이 높은것은 ASH
#
#    - 픽률이 많은것은 GLAZ
#
#    - 두 오퍼레이터들 모두 엔트리( 선두진입 ) 역할을 맡는 오퍼레이터들로, 말하자면 캐리하기 좋다.
# - 수비
#    - 수비팀 승률이 가장 높은것은 FROST와 CAVEIRA
#
#      - 이때 버그가 있어서 FROST의 샷건의 모든 펠릿이 한번음 모여서 날아갔음
#
#      - FROST 특수장비인 덫을 한번 밟는순간 전세가 기울어버린다
#
#    - 픽률이 가장 높은것은 JAGER
#
#    - JAGER와 CAVEIRA는 로머 (거점 밖에서 기습하는것)로 캐리하기 좋은 캐릭터임과 동시에 무장과 특수장비의 성능이 우월함, 둘 다 너프가 필요할것으로 보임
#
#
#    - RESERVE ( 예비군 ) 들을 제외하고는 TACHANKA가 승률과 픽률이 가장 떨어짐 , 상향이 시급한 캐릭터다

# %% [markdown]
# KDA/ WIN 그래프

# %%
sns.relplot(x="k/d_ratio", y="win_ratio", hue="operator", style= "operator" , data=df_graph_ATK).fig.set_size_inches(10,5)
plt.show()

# %%
sns.relplot(x="k/d_ratio", y="win_ratio", hue="operator", style= "operator" , data=df_graph_DEF).fig.set_size_inches(10,5)
plt.show()

# %% [markdown]
# - KDA / Win_ratio  , 밸런스패치를할때 참고하는 형태의 그래프라고 한다.
#
# - 공격
#    - 가장 좋은 오퍼레이터는 ASH ,GLAZ 순
#
#    - 성능이 가장 떨어지는 오퍼레이터는 CAPITAO
#       (RESERVE, 예비병력들 사이에 끼어 있다)
#
# - 수비
#    - 가장 좋은 오퍼레이터는 CAVEIRA , FROST
#
#    - 역시나 TACHANKA는 안쓰러운 성능을 보여준다.
#
#
# - CAVEIRA는 난이도 최상위인것을 제외하면 (게임 내부의 캐릭터 설명: 난이도 최상)
#
# - 승리를 위한 선택
#    - 예거 발키리 밴딧 프로스트
#
#    - 애쉬 글라즈 슬렛지 퓨즈

# %% [markdown]
# # 이상치 탐색 ( 불법 프로그램 / 스머프 )
#
# 이상치 검색부터 진행, 데이터셋은 밸뱃쉘 시즌의 랭크 데이터고 실제 플레이한 데이터이다. 즉 여기서 이상치가 발견된다면 , 불법프로그램 유저 혹은 스머프 (양학러)일 가능성이 높다
#
#  IQR 사용
#
# - 말하자면 불법프로그램과 스머프 유저들의 데이터일 확률이 높음
#
# - 가장 승률이 높은것은 RESERVE ( 예비군 )들 , 기본캐릭터이기 떄문에 핵 실컷 즐기다가 정지당한것으로 보인다.
#
# - 이상치: 일반적인 값보다 상대적으로 큰 데이터 즉 전체 데이터 패턴에서 동떨어져 있는 관측치 , 평균에 영향을 많이 끼치기에 처리해야 하는 데이터

# %% [markdown]
# ## Code

# %%
def outlier_ATK(target):
   q1=df_ATK[target].quantile(0.25)
   q2=df_ATK[target].quantile(0.5)
   q3=df_ATK[target].quantile(0.75)
   iqr=q3-q1
   condition=df_ATK[target]>q3+1.5*iqr
   df_outlier_ATK=df_ATK[condition].dropna()
   return df_outlier_ATK
   
def outlier_DEF(target):
   q1=df_DEF[target].quantile(0.25)
   q2=df_DEF[target].quantile(0.5)
   q3=df_DEF[target].quantile(0.75)
   iqr=q3-q1
   condition=df_DEF[target]>q3+1.5*iqr
   df_outlier_DEF=df_DEF[condition].dropna()
   return df_outlier_DEF

def graph_ATK():
   df_graph_ATK=(df_outlier_ATK[["operator","win_ratio","k/d_ratio","nbpicks"]]
       .sort_values(by="win_ratio" ,ascending=False)
       .groupby(['operator'], as_index=False).mean())
   return df_graph_ATK

def graph_DEF():
   df_graph_DEF=(df_outlier_DEF[["operator","win_ratio","k/d_ratio","nbpicks"]]
       .sort_values(by="win_ratio" ,ascending=False)
       .groupby(['operator'], as_index=False).mean())
   return df_graph_DEF

def except_outlier_ATK():
   df_graph_ATK=(df_ATK[["operator","win_ratio","k/d_ratio","nbpicks"]]
       .sort_values(by="win_ratio" ,ascending=False)
       .groupby(['operator'], as_index=False).mean())
   return df_graph_ATK

def except_outlier_DEF():
   df_graph_DEF=(df_DEF[["operator","win_ratio","k/d_ratio","nbpicks"]]
       .sort_values(by="win_ratio" ,ascending=False)
       .groupby(['operator'], as_index=False).mean())
   return df_graph_DEF

df_outlier_ATK = outlier_ATK("win_ratio")
df_outlier_DEF = outlier_DEF("win_ratio")

df_outlier_ATK_kda = outlier_ATK("k/d_ratio")
df_outlier_DEF_kda = outlier_DEF("k/d_ratio")

df_operators_drop_ATK = df_operators[df_operators["role"]=="Attacker"].drop(df_outlier_ATK.index, axis=0)
df_operators_drop_DEF = df_operators[df_operators["role"]=="Defender"].drop(df_outlier_DEF.index, axis=0)

weapone_ATK = df_operators_drop_ATK.copy()
weapone_DEF = df_operators_drop_DEF.copy()

df_ATK = df_ATK.drop(df_outlier_ATK.index, axis=0)
df_DEF = df_DEF.drop(df_outlier_DEF.index, axis=0)

# %% [markdown]
# ## 그래프 (이상치)
#
# - RESERVE( 예비군)이 승리의 화신이 되었다.

# %%
sns.relplot(x="nbpicks", y="win_ratio", hue="operator", style= "operator" , data=graph_ATK())
plt.show()

# %%
sns.relplot(x="nbpicks", y="win_ratio", hue="operator", style= "operator" , data=graph_DEF())
plt.show()

# %% [markdown]
# - 예비군의 승률이 대부분 1.0 언저리에 있다.
#
# - 특이사항으로는 픽률이 10판조차 못넘겼다는것인데,
#
#  핵 사용자는 정지를 당하고, 양학하던 유저는 랭크가 올라버려 양학을 하지 못하기 때문이라 추측
#
# - 가장 저렴한 패키지를 구매하여 (예비군만 언락되어있던걸로 기억함) 핵으로 실컷 즐기고 도망가는것으로 보인다.

# %%
sns.relplot(x="k/d_ratio", y="win_ratio", hue="operator", style= "operator" , data=graph_ATK())
plt.show()

# %%
sns.relplot(x="k/d_ratio", y="win_ratio", hue="operator", style= "operator" , data=graph_DEF())
plt.show()

# %% [markdown]
# - 전체 그래프에서 종합적으로 최하위를 기록하던 예비군들이 승률 최상위권을 기록하고 있다. 대부분 승률 1.0에 수렴하고 있다

# %%
sns.relplot(x="k/d_ratio", y="win_ratio", hue="operator", style= "operator" , data=except_outlier_ATK())
plt.show()

# %%
sns.relplot(x="k/d_ratio", y="win_ratio", hue="operator", style= "operator" , data=except_outlier_DEF())
plt.show()

# %% [markdown]
# - 결측값을 제외한 데이터
#
# - 이상치가 있고 없고에 따라 예비군 승률의 변화가 보임
#
# - 예비군들은 좌측 하단에 분포되어있다(수비 GSG9 제외 , 무장이 JAGER와 동일하며 성능이 우월하다)

# %% [markdown]
# # 신규캐릭터 적응
#
# - 그래프에 등락폭이 있는데 주말에는 플레이 유저수가 늘어나기 때문으로 추정
#
# - 신규 출시 직후에 픽률이 높고 이후 점점 하락하는 모습을 보임
#
# - 약 한달정도 지나면 픽률이 안정화 되는것으로 보임

# %% [markdown]
# ## Code

# %%
ATK_NewOper = df_operators[df_operators["role"]=="Attacker"][["dateid","operator","win_ratio","k/d_ratio","nbpicks"]]
DEF_NewOper = df_operators[df_operators["role"]=="Defender"][["dateid","operator","win_ratio","k/d_ratio","nbpicks"]]

# %%
ATK_NewOper["dateid"] = ATK_NewOper["dateid"].apply(lambda x : pd.to_datetime(str(x) , format = "%Y-%m-%d"))
DEF_NewOper["dateid"] = DEF_NewOper["dateid"].apply(lambda x : pd.to_datetime(str(x) , format = "%Y-%m-%d"))

# %%
ATK_Newoper = ATK_NewOper[ATK_NewOper["operator"]=="G.E.O.-JACKAL"]
DEF_Newoper = DEF_NewOper[DEF_NewOper["operator"]=="G.E.O.-MIRA"]

# %% [markdown]
# ## 그래프

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.lineplot(x="dateid" , y="nbpicks", data=ATK_Newoper)

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.lineplot(x="dateid" , y="nbpicks", data=DEF_Newoper)

# %% [markdown]
# # 공/수 무기별 KDA ,선호도
#
# - 전체 유저의 무기 선호도 그리고 예측 KDA를 트리구조로 표현해볼생각이다.
#
# - 수비팀은 SG의 성능이 제법 괜찮고 , 왠만해선 한팀에 하나는 챙겨가는 편이다,
#
# - 그러니 공격팀보다는 수비팀의 샷건 KDA가 좀더 높을것이다( 물론 다른 총기 대비 낮을것 )

# %% [markdown]
# ## Code

# %%
AR = ["PARA-308" , "C7E" , "416-C CARBINE" , "F2" ,"C8-SFW", "AUG A2", "552 COMMANDO","AR33" , "L85A2" , "G36C" , "AK-12" , "R4-C" , "556XI" ,"TYPE-89", "MK17 CQB"] 
SMG = ["PDW9" , "UMP45","MP5" ,"P90" , "9mm C1","VECTOR .45 ACP","9x19VSN" ,"FMG-9", "MP5SD" , "MPX", "MP7" , "M12","MP5K"]  
SG = ["SG-CQB","M1014" , "SASG-12" , "SuperNova" , "SPAS-12" , "M590A1","M870","ITA12L","SUPER 90","SPAS-15",""]
SR = ["HK417" , "C8-SFW"  , "CAMRS" ,"OTs-03","SR-25"]
LMG = ["M249", "G8A1" , "6P41"]

for ar  in AR :
  df_operators_drop_ATK = df_operators_drop_ATK.replace(ar , "AR")
  df_operators_drop_DEF = df_operators_drop_DEF.replace(ar , "AR")
for smg in SMG:
  df_operators_drop_ATK = df_operators_drop_ATK.replace(smg , "SMG")
  df_operators_drop_DEF = df_operators_drop_DEF.replace(smg , "SMG")
for sg in SG:
  df_operators_drop_ATK = df_operators_drop_ATK.replace(sg , "SG")
  df_operators_drop_DEF = df_operators_drop_DEF.replace(sg , "SG")
for sr in SR:
  df_operators_drop_ATK = df_operators_drop_ATK.replace(sr , "SR")
  df_operators_drop_DEF = df_operators_drop_DEF.replace(sr , "SR")
for lmg in LMG:
  df_operators_drop_ATK = df_operators_drop_ATK.replace(lmg , "LMG")
  df_operators_drop_DEF = df_operators_drop_DEF.replace(lmg , "LMG")

# %%
ATK_encoder_KD = df_operators_drop_ATK
ATK_encoder_WIN = df_operators_drop_ATK

DEF_encoder_KD = df_operators_drop_DEF
DEF_encoder_WIN = df_operators_drop_DEF

# %%
from category_encoders import OneHotEncoder
from sklearn.tree import DecisionTreeRegressor

encoder_ATK = OneHotEncoder(use_cat_names= True)
encoder_DEF = OneHotEncoder(use_cat_names= True)

ATK_encoder_KD = encoder_ATK.fit_transform(ATK_encoder_KD)
DEF_encoder_KD = encoder_DEF.fit_transform(DEF_encoder_KD)

# %% [markdown]
# 결정트리로 각 무기별 KDA를 시각화 하여 한눈에 보고싶다.
#
# 회귀나무 (regression tree)로 진행

# %%
import graphviz
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor,export_graphviz
from sklearn.metrics import accuracy_score
weapon_list_ATK = ["primaryweapon_LMG", "primaryweapon_AR" ,"primaryweapon_SMG","primaryweapon_Shield","primaryweapon_SR","primaryweapon_SG"]
weapon_list_DEF = ["primaryweapon_AR" ,"primaryweapon_SMG","primaryweapon_SG"]

# %%
def DTR_ATK(target):
  tree_reg_ATK = DecisionTreeRegressor()

  col_ATK = ATK_encoder_KD[weapon_list_ATK]

  target = ATK_encoder_KD[[target]]

  X_train , X_test , y_train, y_test = train_test_split(col_ATK , target , test_size = 0.2 , random_state=11)
  tree_reg_ATK.fit(X_train, y_train)
  y_pred=tree_reg_ATK.predict(X_test)
  accur=tree_reg_ATK.score(X_test,y_pred)

  return print(accur)


def DTR_DEF(target):
  tree_reg_DEF = DecisionTreeRegressor()

  col_DEF = DEF_encoder_KD[weapon_list_DEF]

  target = DEF_encoder_KD[[target]]

  X_train , X_test , y_train, y_test = train_test_split(col_DEF , target , test_size = 0.2 , random_state=11)
  tree_reg_DEF.fit(X_train, y_train)

  y_pred=tree_reg_DEF.predict(X_test)
  accur=tree_reg_DEF.score(X_test,y_pred)
  return print(accur)

def show_tree(tree, colnames):
    dot = export_graphviz(tree, feature_names=colnames, filled=True, rounded=True)   
    return graphviz.Source(dot)

# %%
DTR_ATK("k/d_ratio")
DTR_DEF("k/d_ratio")
DTR_ATK("win_ratio")
DTR_DEF("win_ratio")
# Out:
# 1.0
# 1.0
# 1.0
# 1.0

# %%
def TREE_ATK(target):
  col_ATK = ATK_encoder_KD[ATK_encoder_KD.columns]
  target_ATK = ATK_encoder_KD[target]
  tree_ATK = DecisionTreeRegressor()
  tree_ATK.fit(col_ATK[weapon_list_ATK], target_ATK)

  return tree_ATK

def TREE_DEF(target):
  col_DEF = DEF_encoder_KD[DEF_encoder_KD.columns]
  target_DEF = DEF_encoder_KD[[target]]
  tree_DEF = DecisionTreeRegressor()
  tree_DEF.fit(col_DEF[weapon_list_DEF], target_DEF)

  return tree_DEF

# %% [markdown]
# ## 그래프

# %%
show_tree(TREE_ATK("k/d_ratio"), colnames=weapon_list_ATK)

# %%
show_tree(TREE_DEF("k/d_ratio"), colnames=weapon_list_DEF)

# %% [markdown]
# - 단순히 해당 무기를 들고 갔을때 실전에서 어느정도의 KDA를 기록할지 확인할 수 있다.

# %%
show_tree(TREE_ATK("win_ratio"), colnames=weapon_list_ATK)

# %%
show_tree(TREE_DEF("win_ratio"), colnames=weapon_list_DEF)

# %% [markdown]
# 승률에 따른 회귀트리

# %% [markdown]
# # 플랫폼별 승률, KDA 차이
#
#
# 1. 콘솔로 플레이하는 사람들은 선호하는 무기가 다를까?
#
# 2. 만약 선호하는 무기가 다르고, 각 캐릭터별 주력 총기가 다르다면, 밸런스 패치를 다르게 진행해야한다
#
# 3. 머리한번만 쏘면 죽는 게임이니 PC는 SMG와 AR이 지배하고 있다.
#  하지만 조준이 어려운 콘솔은 샷건의 선호도가 좀 더 높지 않을까 싶다

# %% [markdown]
# ## 플랫폼별 KDA , Win_ratio

# %%
print("DEF_K/DA",df_operators_drop_DEF[["platform","k/d_ratio"]].groupby("platform").mean())
print()
print("ATK_K/DA",df_operators_drop_ATK[["platform","k/d_ratio"]].groupby("platform").mean())
# Out:
# DEF_K/DA           k/d_ratio
# platform
# PC         0.845214
# PS4        0.794322
# XONE       0.798116
#
# ATK_K/DA           k/d_ratio
# platform
# PC         0.858801
# PS4        0.901558
# XONE       0.903808

# %%
print("DEF_win", df_operators_drop_DEF[["platform","win_ratio"]].groupby("platform").mean())
print()
print("ATK_win", df_operators_drop_ATK[["platform","win_ratio"]].groupby("platform").mean())
# Out:
# DEF_win           win_ratio
# platform
# PC         0.449866
# PS4        0.450440
# XONE       0.450463
#
# ATK_win           win_ratio
# platform
# PC         0.400803
# PS4        0.459416
# XONE       0.453613

# %% [markdown]
# - 콘솔에서는 평균적으로 공격팀의 평균 KDA가 더 높음, 교전시 공격팀이 더욱 유리한것을 볼수 있음
#
# - 콘솔 승률은 서로 비슷하며 최종적으로 공수 밸런스는 맞다고 볼 수 있음
#
# -  PC의 승률은 차이가 있는데 이는 수비팀이 공격팀보다 유리하다는것을 의미함
#
# - 콘솔의 경우 헤드샷을 노리기 어려워 서로 화력싸움을 하는 비율이 높기에 수비팀보다 공격팀의 KDA가 높은듯 하다.

# %% [markdown]
# ## Code

# %%
df_operators_drop_ATK = df_operators_drop_ATK.replace("PS4" , "CONSOLE").replace("XONE","CONSOLE")
df_operators_drop_DEF = df_operators_drop_DEF.replace("PS4" , "CONSOLE").replace("XONE","CONSOLE")

# %%
def TREE_ATK(target):
  col_ATK = ATK_encoder_KD[ATK_encoder_KD.columns]
  target_ATK = ATK_encoder_KD["win_ratio"]
  tree_ATK = DecisionTreeRegressor()
  tree_ATK.fit(col_ATK[weapon_list_ATK], target_ATK)

  return tree_ATK

# %%
weapone_ATK=weapone_ATK.replace("XONE","CONSOLE")
weapone_ATK=weapone_ATK.replace("PS4","CONSOLE")

weapone_DEF=weapone_DEF.replace("XONE","CONSOLE")
weapone_DEF=weapone_DEF.replace("PS4","CONSOLE")

# %%
PC_ATK = weapone_ATK[weapone_ATK["platform"]=="PC"]
CONSOLE_ATK = weapone_ATK[(weapone_ATK["platform"]=="CONSOLE") ]

PC_DEF = weapone_DEF[weapone_DEF["platform"]=="PC"]
CONSOLE_DEF = weapone_DEF[(weapone_DEF["platform"]=="CONSOLE") ]

# %%
def weapon_chart_PC_ATK(target ,x, y):
    weapone_ATK_PC= PC_ATK.groupby("primaryweapon").mean().sort_values(by=target)
    plt.figure(figsize=(x,y))

    return sns.barplot(x=weapone_ATK_PC[target], y=weapone_ATK_PC.index, data=weapone_ATK_PC).set_title("PC_ATK")

def weapon_chart_PC_DEF(target, x, y):
    weapone_DEF_PC= PC_DEF.groupby("primaryweapon").mean().sort_values(by=target)
    plt.figure(figsize=(x,y))

    return sns.barplot(x=weapone_DEF_PC[target], y=weapone_DEF_PC.index, data=weapone_DEF_PC).set_title("PC_DEF")

def weapon_chart_CON_ATK(target,x,y):
    weapone_ATK_CON= CONSOLE_ATK.groupby("primaryweapon").mean().sort_values(by=target)
    plt.figure(figsize=(x,y))

    return sns.barplot(x=weapone_ATK_CON[target], y=weapone_ATK_CON.index, data=weapone_ATK_CON).set_title("CON_ATK")

def weapon_chart_CON_DEF(target, x, y):
    weapone_DEF_CON= CONSOLE_DEF.groupby("primaryweapon").mean().sort_values(by=target)
    plt.figure(figsize=(x,y))

    return sns.barplot(x=weapone_DEF_CON[target], y=weapone_DEF_CON.index, data=weapone_DEF_CON).set_title("CON_DEF")

# %% [markdown]
# ## 그래프

# %%
sns.barplot(data=df_operators_drop_ATK,
            x="primaryweapon",
            y="k/d_ratio",
            hue="platform")

# %% [markdown]
# - 콘솔은 헤드샷을 맞추기 어렵다.
#
#     (PC가 콘솔보다 유리한건 일반적인 현상이다. 조이스틱으로 정조준하기 힘들기 때문)
#
# - 샷건이 KDA차이가 꽤 심하게 난다. 그리고 전체적으로 콘솔의 KDA가 높게 나왔다.
#
#
# - 공격팀의 무장은 몇몇 오퍼레이터들을 제외하곤 화력으로 압도할수 있다. 그렇기에 PC의 경우 SMG를 이용해 헤드샷을 노려 화력차팀를 이겨낸것으로 보인다.
#
# -  콘솔유저들은 헤드샷을 잘 맞추지 못한다. 그렇기에 헤드샷을 맞기 전에 샷건으로 사살하였기 때문에 콘솔의 샷건 K/DA 격차가 더 크게 벌어진듯 하다.

# %%
sns.barplot(data=df_operators_drop_DEF,
            x="primaryweapon",
            y="k/d_ratio",
            hue="platform")

# %% [markdown]
# - 수비팀& PC 의 SMG K/DA 격차가 벌어져있음
#
# - PC & CONSOLE의 SMG KDA가 차이나는것을 보아 PC의 SMG 사용자는 공격팀과 마찬가지로 헤드샷노려 화력차이를 이겨낸것으로 보인다

# %%
weapon_chart_PC_ATK("k/d_ratio",15,5)
# Out:
# Text(0.5, 1.0, 'PC_ATK')

# %%
weapon_chart_CON_ATK("k/d_ratio",15,5)
# Out:
# Text(0.5, 1.0, 'CON_ATK')

# %%
weapon_chart_PC_DEF("k/d_ratio",15,5)
# Out:
# Text(0.5, 1.0, 'PC_DEF')

# %%
weapon_chart_CON_DEF("k/d_ratio",15,5)
# Out:
# Text(0.5, 1.0, 'CON_DEF')

# %% [markdown]
# - 이 시즌때 FROST의 샷건인 SUPER 90 에는 버그가 있었다고 한다.
#
#  샷건 펠릿이 한곳에 모여서 날아가는 버그였다고 하는데 굉장히 강력했다고 한다.
#
#  하지만 실질적으로 큰 킬 결정능력은 많이 부족했던것으로 보인다.
#
#
#
# - 콘솔의 최고의 킬 결정능력을 가지고 있는 무기는 G36C , PC는 MK17 CQB
#
#  MK17 CQB는 BLACK BEARD 오퍼레이터의 무장으로 BLACK BEARD는 머리를 보호하는 총기방패를 특수장비로 가지고 있다.
#
#  헤드샷을 노리는 PC 환경에서는 굉장히 강력한 성능을 발휘하나, 그것이 어려운 콘솔 환경에서는 살짝 밀리는 모습을 보여준다.

# %%
weapon_chart_PC_ATK("win_ratio",15,5)
# Out:
# Text(0.5, 1.0, 'PC_ATK')

# %%
weapon_chart_CON_ATK("win_ratio",15,5)
# Out:
# Text(0.5, 1.0, 'CON_ATK')

# %%
weapon_chart_PC_DEF("win_ratio",15,5)
# Out:
# Text(0.5, 1.0, 'PC_DEF')

# %%
weapon_chart_CON_DEF("win_ratio",15,5)
# Out:
# Text(0.5, 1.0, 'CON_DEF')

# %% [markdown]
# - 다른 샷건은 안좋은 순위를 기록하고 있으나 SUPER 90 이라는 샷건은 최상위권을 기록하였다. 하지만 위에서 본 그래프를 보면 킬 결정능력은 부족하였다. 즉 샷건을 이용해서 승리를 거뒀다기 보다는, 특수장비인 곰덫의 영향이 큰것으로 보인다.

# %% [markdown]
# # 맵별 공수 승률
#
# - 여기 플랫폼은 전부 PC뿐이다

# %% [markdown]
# ## Code

# %%
INDEX_obj    = df_objectives[df_objectives["nbdeaths"]==0].index
df_objectives= df_objectives.drop(INDEX_obj)

# %%
objectives_BOMB = df_objectives[df_objectives["gamemode"]=="PvP . BOMB"]

# %%
objectives_BOMB=objectives_BOMB[["mapname","objectivelocation","skillrank","role","operator","k/d_ratio","win_ratio"]].sort_values(by="win_ratio")

# %%
def map_graph(target_x, target_y , HUE , DATA):  
   plt.figure(figsize=(6,6))
   return sns.barplot(data=DATA,
                y=target_y,
                x=target_x,
                hue=HUE)

# %% [markdown]
# ## 그래프

# %%
map_graph("win_ratio","mapname","role",objectives_BOMB)

# %%
map_graph("k/d_ratio","mapname","role",objectives_BOMB)

# %% [markdown]
# - 공격팀이 KDA가 더 높더라도 승률은 수비팀과 비슷하거나 수비팀이 더 높다.
#
# - 단순히 킬을 많이 하더라도 승리로 이어지는것은 아니라는것을 알 수 있음

# %%
MAP_LIST=objectives_BOMB[objectives_BOMB["mapname"].isin(["BANK"])]
map_graph("win_ratio","objectivelocation","role",MAP_LIST)

# %% [markdown]
# - BANK
#    - EXECUTIVE LOUNGE / CEO OFFICE = 2층
#    - LOCKERS / CCTV ROOM  = 지하
#    - STAFF ROOM / OPEN AREA  1층
#    - TELLERS OFFICE 1층

# %%
MAP_LIST=objectives_BOMB[objectives_BOMB["mapname"].isin(['CLUB HOUSE'])]
map_graph("win_ratio","objectivelocation","role",MAP_LIST)

# %% [markdown]
# - CLUB HOUST
#    - GYM / BEDROOM  2층  :
#    - CHRUCH / ARSENAL ROOM 지하
#    - CCTV ROOM / CASH ROOM 2층
#    - BAR / STOCK ROOM  1층
#
# - 맵 전체적으로 수정할 필요가 있음
#
# - 특히 2층은 압도적으로 공격팀이 더 유리함 공격팀이 불리하게 수정할 필요가 있어보임
#
# - 지하는 수비팀이 더 유리한데 , 지하라는 특성상 진입 가능한 루트가 한정되어 있음 , 그렇기에 버티컬 역할을 수행하는 오퍼레이터 ( SLEDGE, BUCK)을 상향하거나, 천장 해치를 늘리는 방법이 있음

# %%
MAP_LIST=objectives_BOMB[objectives_BOMB["mapname"].isin(["COASTLINE"])]
map_graph("win_ratio","objectivelocation","role",MAP_LIST)

# %% [markdown]
# - 밸런스가 잘 잡힌 맵, 2층 팬트하우스를 제외하고는 비슷한 승률을 보여주고 있음,
#
# - 밸런스를 맞추기 위해서는 1층은 그대로 두고 2층만 손보는것이 좋아보임

# %%
MAP_LIST=objectives_BOMB[objectives_BOMB["mapname"].isin(["HEREFORD BASE"])]
map_graph("win_ratio","objectivelocation","role",MAP_LIST)

# %% [markdown]
# - COASTLINE
#    - HOOKAH LOUNGE / 2F BILLIARDS ROOM  2층
#    - PENTHOUSE/ THEATHER 2층
#    - KITCHEN / SERVICE ENTRANCE
#    - 1F BLUE BAR /1F SUNRISE BAR 1층

# %% [markdown]
# # 불법프로그램 사용자, 스머프 추정 유저 분리

# %% [markdown]
# ## Code

# %%
from lightgbm import LGBMClassifier
import time
import warnings

df_outlier_ATK["hax"]=1
df_ATK["hax"]=0

df_gb=pd.concat([df_outlier_ATK,df_ATK])

features = df_gb[["win_ratio", "k/d_ratio","nbpicks"]]
target = df_gb["hax"]

X_train, X_test, y_train, y_test = train_test_split(features, target , test_size = 0.3 , random_state=11)

# %%
lgbm_wrapper = LGBMClassifier(n_estimators=300, learning_rate=0.05)

# %%
evals = [(X_test, y_test)]
lgbm_wrapper.fit(X_train, y_train, early_stopping_rounds=50, eval_metric="logloss", 
                 eval_set=evals, verbose=True)
preds = lgbm_wrapper.predict(X_test)
pred_proba = lgbm_wrapper.predict_proba(X_test)[:, 1]
# Out:
# [1]	valid_0's binary_logloss: 0.166146	valid_0's binary_logloss: 0.166146
# Training until validation scores don't improve for 50 rounds.
# [2]	valid_0's binary_logloss: 0.145092	valid_0's binary_logloss: 0.145092
# [3]	valid_0's binary_logloss: 0.130161	valid_0's binary_logloss: 0.130161
# [4]	valid_0's binary_logloss: 0.11841	valid_0's binary_logloss: 0.11841
# [5]	valid_0's binary_logloss: 0.108669	valid_0's binary_logloss: 0.108669
# [6]	valid_0's binary_logloss: 0.100336	valid_0's binary_logloss: 0.100336
# [7]	valid_0's binary_logloss: 0.0930568	valid_0's binary_logloss: 0.0930568
# [8]	valid_0's binary_logloss: 0.0866031	valid_0's binary_logloss: 0.0866031
# [9]	valid_0's binary_logloss: 0.0808168	valid_0's binary_logloss: 0.0808168
# [10]	valid_0's binary_logloss: 0.0755843	valid_0's binary_logloss: 0.0755843
# [11]	valid_0's binary_logloss: 0.0708201	valid_0's binary_logloss: 0.0708201
# [12]	valid_0's binary_logloss: 0.0664587	valid_0's binary_logloss: 0.0664587
# [13]	valid_0's binary_logloss: 0.0624477	valid_0's binary_logloss: 0.0624477
# [14]	valid_0's binary_logloss: 0.0587453	valid_0's binary_logloss: 0.0587453
# [15]	valid_0's binary_logloss: 0.0553168	valid_0's binary_logloss: 0.0553168
# [16]	valid_0's binary_logloss: 0.0521332	valid_0's binary_logloss: 0.0521332
# [17]	valid_0's binary_logloss: 0.0491703	valid_0's binary_logloss: 0.0491703
# [18]	valid_0's binary_logloss: 0.0464072	valid_0's binary_logloss: 0.0464072
# [19]	valid_0's binary_logloss: 0.0438258	valid_0's binary_logloss: 0.0438258
# [20]	valid_0's binary_logloss: 0.0414104	valid_0's binary_logloss: 0.0414104
# [21]	valid_0's binary_logloss: 0.0391473	valid_0's binary_logloss: 0.0391473
# [22]	valid_0's binary_logloss: 0.0370242	valid_0's binary_logloss: 0.0370242
# [23]	valid_0's binary_logloss: 0.0350303	valid_0's binary_logloss: 0.0350303
# [24]	valid_0's binary_logloss: 0.0331559	valid_0's binary_logloss: 0.0331559
# [25]	valid_0's binary_logloss: 0.0313923	valid_0's binary_logloss: 0.0313923
# [26]	valid_0's binary_logloss: 0.0297316	valid_0's binary_logloss: 0.0297316
# [27]	valid_0's binary_logloss: 0.0281667	valid_0's binary_logloss: 0.0281667
# [28]	valid_0's binary_logloss: 0.0266911	valid_0's binary_logloss: 0.0266911
# [29]	valid_0's binary_logloss: 0.0252988	valid_0's binary_logloss: 0.0252988
# [30]	valid_0's binary_logloss: 0.0239845	valid_0's binary_logloss: 0.0239845
# [31]	valid_0's binary_logloss: 0.0227431	valid_0's binary_logloss: 0.0227431
# [32]	valid_0's binary_logloss: 0.02157	valid_0's binary_logloss: 0.02157
# [33]	valid_0's binary_logloss: 0.020461	valid_0's binary_logloss: 0.020461
# [34]	valid_0's binary_logloss: 0.0194123	valid_0's binary_logloss: 0.0194123
# [35]	valid_0's binary_logloss: 0.0184201	valid_0's binary_logloss: 0.0184201
# [36]	valid_0's binary_logloss: 0.0174811	valid_0's binary_logloss: 0.0174811
# [37]	valid_0's binary_logloss: 0.0165922	valid_0's binary_logloss: 0.0165922
# [38]	valid_0's binary_logloss: 0.0157505	valid_0's binary_logloss: 0.0157505
# [39]	valid_0's binary_logloss: 0.0149532	valid_0's binary_logloss: 0.0149532
# [40]	valid_0's binary_logloss: 0.0141978	valid_0's binary_logloss: 0.0141978
# [41]	valid_0's binary_logloss: 0.0134819	valid_0's binary_logloss: 0.0134819
# [42]	valid_0's binary_logloss: 0.0128034	valid_0's binary_logloss: 0.0128034
# [43]	valid_0's binary_logloss: 0.0121601	valid_0's binary_logloss: 0.0121601
# [44]	valid_0's binary_logloss: 0.0115501	valid_0's binary_logloss: 0.0115501
# [45]	valid_0's binary_logloss: 0.0109715	valid_0's binary_logloss: 0.0109715
# [46]	valid_0's binary_logloss: 0.0104228	valid_0's binary_logloss: 0.0104228
# [47]	valid_0's binary_logloss: 0.00990214	valid_0's binary_logloss: 0.00990214
# [48]	valid_0's binary_logloss: 0.00940814	valid_0's binary_logloss: 0.00940814
# [49]	valid_0's binary_logloss: 0.00893934	valid_0's binary_logloss: 0.00893934
# [50]	valid_0's binary_logloss: 0.00849441	valid_0's binary_logloss: 0.00849441
# [51]	valid_0's binary_logloss: 0.00807207	valid_0's binary_logloss: 0.00807207
# [52]	valid_0's binary_logloss: 0.00767113	valid_0's binary_logloss: 0.00767113
# [53]	valid_0's binary_logloss: 0.00729046	valid_0's binary_logloss: 0.00729046
# [54]	valid_0's binary_logloss: 0.00692901	valid_0's binary_logloss: 0.00692901
# [55]	valid_0's binary_logloss: 0.00658577	valid_0's binary_logloss: 0.00658577
# [56]	valid_0's binary_logloss: 0.00625979	valid_0's binary_logloss: 0.00625979
# [57]	valid_0's binary_logloss: 0.00595018	valid_0's binary_logloss: 0.00595018
# [58]	valid_0's binary_logloss: 0.0056561	valid_0's binary_logloss: 0.0056561
# [59]	valid_0's binary_logloss: 0.00537674	valid_0's binary_logloss: 0.00537674
# [60]	valid_0's binary_logloss: 0.00511135	valid_0's binary_logloss: 0.00511135
# [61]	valid_0's binary_logloss: 0.00485921	valid_0's binary_logloss: 0.00485921
# [62]	valid_0's binary_logloss: 0.00461965	valid_0's binary_logloss: 0.00461965
# [63]	valid_0's binary_logloss: 0.00439202	valid_0's binary_logloss: 0.00439202
# [64]	valid_0's binary_logloss: 0.00417573	valid_0's binary_logloss: 0.00417573
# [65]	valid_0's binary_logloss: 0.00397018	valid_0's binary_logloss: 0.00397018
# [66]	valid_0's binary_logloss: 0.00377484	valid_0's binary_logloss: 0.00377484
# [67]	valid_0's binary_logloss: 0.0035892	valid_0's binary_logloss: 0.0035892
# [68]	valid_0's binary_logloss: 0.00341276	valid_0's binary_logloss: 0.00341276
# [69]	valid_0's binary_logloss: 0.00324506	valid_0's binary_logloss: 0.00324506
# [70]	valid_0's binary_logloss: 0.00308566	valid_0's binary_logloss: 0.00308566
# [71]	valid_0's binary_logloss: 0.00293414	valid_0's binary_logloss: 0.00293414
# [72]	valid_0's binary_logloss: 0.00279012	valid_0's binary_logloss: 0.00279012
# [73]	valid_0's binary_logloss: 0.0026532	valid_0's binary_logloss: 0.0026532
# [74]	valid_0's binary_logloss: 0.00252305	valid_0's binary_logloss: 0.00252305
# [75]	valid_0's binary_logloss: 0.00239931	valid_0's binary_logloss: 0.00239931
# [76]	valid_0's binary_logloss: 0.00228168	valid_0's binary_logloss: 0.00228168
# [77]	valid_0's binary_logloss: 0.00216984	valid_0's binary_logloss: 0.00216984
# [78]	valid_0's binary_logloss: 0.00206351	valid_0's binary_logloss: 0.00206351
# [79]	valid_0's binary_logloss: 0.00196242	valid_0's binary_logloss: 0.00196242
# [80]	valid_0's binary_logloss: 0.0018663	valid_0's binary_logloss: 0.0018663
# [81]	valid_0's binary_logloss: 0.00177491	valid_0's binary_logloss: 0.00177491
# [82]	valid_0's binary_logloss: 0.00168801	valid_0's binary_logloss: 0.00168801
# [83]	valid_0's binary_logloss: 0.00160538	valid_0's binary_logloss: 0.00160538
# [84]	valid_0's binary_logloss: 0.00152681	valid_0's binary_logloss: 0.00152681
# [85]	valid_0's binary_logloss: 0.0014521	valid_0's binary_logloss: 0.0014521
# [86]	valid_0's binary_logloss: 0.00138105	valid_0's binary_logloss: 0.00138105
# [87]	valid_0's binary_logloss: 0.00131349	valid_0's binary_logloss: 0.00131349
# [88]	valid_0's binary_logloss: 0.00124925	valid_0's binary_logloss: 0.00124925
# [89]	valid_0's binary_logloss: 0.00118816	valid_0's binary_logloss: 0.00118816
# [90]	valid_0's binary_logloss: 0.00113006	valid_0's binary_logloss: 0.00113006
# [91]	valid_0's binary_logloss: 0.00107481	valid_0's binary_logloss: 0.00107481
# [92]	valid_0's binary_logloss: 0.00102227	valid_0's binary_logloss: 0.00102227
# [93]	valid_0's binary_logloss: 0.0009723	valid_0's binary_logloss: 0.0009723
# [94]	valid_0's binary_logloss: 0.00092478	valid_0's binary_logloss: 0.00092478
# [95]	valid_0's binary_logloss: 0.000879587	valid_0's binary_logloss: 0.000879587
# [96]	valid_0's binary_logloss: 0.000836607	valid_0's binary_logloss: 0.000836607
# [97]	valid_0's binary_logloss: 0.000795731	valid_0's binary_logloss: 0.000795731
# [98]	valid_0's binary_logloss: 0.000756855	valid_0's binary_logloss: 0.000756855
# [99]	valid_0's binary_logloss: 0.000719882	valid_0's binary_logloss: 0.000719882
# [100]	valid_0's binary_logloss: 0.000684718	valid_0's binary_logloss: 0.000684718
# [101]	valid_0's binary_logloss: 0.000651274	valid_0's binary_logloss: 0.000651274
# [102]	valid_0's binary_logloss: 0.000619466	valid_0's binary_logloss: 0.000619466
# [103]	valid_0's binary_logloss: 0.000589214	valid_0's binary_logloss: 0.000589214
# [104]	valid_0's binary_logloss: 0.000560441	valid_0's binary_logloss: 0.000560441
# [105]	valid_0's binary_logloss: 0.000533074	valid_0's binary_logloss: 0.000533074
# [106]	valid_0's binary_logloss: 0.000507046	valid_0's binary_logloss: 0.000507046
# [107]	valid_0's binary_logloss: 0.00048229	valid_0's binary_logloss: 0.00048229
# [108]	valid_0's binary_logloss: 0.000458744	valid_0's binary_logloss: 0.000458744
# [109]	valid_0's binary_logloss: 0.000436348	valid_0's binary_logloss: 0.000436348
# [110]	valid_0's binary_logloss: 0.000415047	valid_0's binary_logloss: 0.000415047
# [111]	valid_0's binary_logloss: 0.000394787	valid_0's binary_logloss: 0.000394787
# [112]	valid_0's binary_logloss: 0.000375516	valid_0's binary_logloss: 0.000375516
# [113]	valid_0's binary_logloss: 0.000357187	valid_0's binary_logloss: 0.000357187
# [114]	valid_0's binary_logloss: 0.000339753	valid_0's binary_logloss: 0.000339753
# [115]	valid_0's binary_logloss: 0.000323171	valid_0's binary_logloss: 0.000323171
# [116]	valid_0's binary_logloss: 0.000307399	valid_0's binary_logloss: 0.000307399
# [117]	valid_0's binary_logloss: 0.000292397	valid_0's binary_logloss: 0.000292397
# [118]	valid_0's binary_logloss: 0.000278128	valid_0's binary_logloss: 0.000278128
# [119]	valid_0's binary_logloss: 0.000264555	valid_0's binary_logloss: 0.000264555
# [120]	valid_0's binary_logloss: 0.000251645	valid_0's binary_logloss: 0.000251645
# [121]	valid_0's binary_logloss: 0.000239365	valid_0's binary_logloss: 0.000239365
# [122]	valid_0's binary_logloss: 0.000227685	valid_0's binary_logloss: 0.000227685
# [123]	valid_0's binary_logloss: 0.000216576	valid_0's binary_logloss: 0.000216576
# [124]	valid_0's binary_logloss: 0.000206008	valid_0's binary_logloss: 0.000206008
# [125]	valid_0's binary_logloss: 0.000195956	valid_0's binary_logloss: 0.000195956
# [126]	valid_0's binary_logloss: 0.000186395	valid_0's binary_logloss: 0.000186395
# [127]	valid_0's binary_logloss: 0.000177301	valid_0's binary_logloss: 0.000177301
# [128]	valid_0's binary_logloss: 0.000168651	valid_0's binary_logloss: 0.000168651
# [129]	valid_0's binary_logloss: 0.000160423	valid_0's binary_logloss: 0.000160423
# [130]	valid_0's binary_logloss: 0.000152596	valid_0's binary_logloss: 0.000152596
# [131]	valid_0's binary_logloss: 0.000145151	valid_0's binary_logloss: 0.000145151
# [132]	valid_0's binary_logloss: 0.00013807	valid_0's binary_logloss: 0.00013807
# [133]	valid_0's binary_logloss: 0.000131334	valid_0's binary_logloss: 0.000131334
# [134]	valid_0's binary_logloss: 0.000124927	valid_0's binary_logloss: 0.000124927
# [135]	valid_0's binary_logloss: 0.000118833	valid_0's binary_logloss: 0.000118833
# [136]	valid_0's binary_logloss: 0.000113036	valid_0's binary_logloss: 0.000113036
# [137]	valid_0's binary_logloss: 0.000107522	valid_0's binary_logloss: 0.000107522
# [138]	valid_0's binary_logloss: 0.000102276	valid_0's binary_logloss: 0.000102276
# [139]	valid_0's binary_logloss: 9.72872e-05	valid_0's binary_logloss: 9.72872e-05
# [140]	valid_0's binary_logloss: 9.25415e-05	valid_0's binary_logloss: 9.25415e-05
# [141]	valid_0's binary_logloss: 8.80273e-05	valid_0's binary_logloss: 8.80273e-05
# [142]	valid_0's binary_logloss: 8.37333e-05	valid_0's binary_logloss: 8.37333e-05
# [143]	valid_0's binary_logloss: 7.96488e-05	valid_0's binary_logloss: 7.96488e-05
# [144]	valid_0's binary_logloss: 7.57637e-05	valid_0's binary_logloss: 7.57637e-05
# [145]	valid_0's binary_logloss: 7.2068e-05	valid_0's binary_logloss: 7.2068e-05
# [146]	valid_0's binary_logloss: 6.85527e-05	valid_0's binary_logloss: 6.85527e-05
# [147]	valid_0's binary_logloss: 6.52088e-05	valid_0's binary_logloss: 6.52088e-05
# [148]	valid_0's binary_logloss: 6.20281e-05	valid_0's binary_logloss: 6.20281e-05
# [149]	valid_0's binary_logloss: 5.90025e-05	valid_0's binary_logloss: 5.90025e-05
# [150]	valid_0's binary_logloss: 5.61246e-05	valid_0's binary_logloss: 5.61246e-05
# [151]	valid_0's binary_logloss: 5.3387e-05	valid_0's binary_logloss: 5.3387e-05
# [152]	valid_0's binary_logloss: 5.0783e-05	valid_0's binary_logloss: 5.0783e-05
# [153]	valid_0's binary_logloss: 4.8306e-05	valid_0's binary_logloss: 4.8306e-05
# [154]	valid_0's binary_logloss: 4.59499e-05	valid_0's binary_logloss: 4.59499e-05
# [155]	valid_0's binary_logloss: 4.37086e-05	valid_0's binary_logloss: 4.37086e-05
# [156]	valid_0's binary_logloss: 4.15767e-05	valid_0's binary_logloss: 4.15767e-05
# [157]	valid_0's binary_logloss: 3.95488e-05	valid_0's binary_logloss: 3.95488e-05
# [158]	valid_0's binary_logloss: 3.76198e-05	valid_0's binary_logloss: 3.76198e-05
# [159]	valid_0's binary_logloss: 3.5785e-05	valid_0's binary_logloss: 3.5785e-05
# [160]	valid_0's binary_logloss: 3.40396e-05	valid_0's binary_logloss: 3.40396e-05
# [161]	valid_0's binary_logloss: 3.23793e-05	valid_0's binary_logloss: 3.23793e-05
# [162]	valid_0's binary_logloss: 3.08e-05	valid_0's binary_logloss: 3.08e-05
# [163]	valid_0's binary_logloss: 2.92978e-05	valid_0's binary_logloss: 2.92978e-05
# [164]	valid_0's binary_logloss: 2.78688e-05	valid_0's binary_logloss: 2.78688e-05
# [165]	valid_0's binary_logloss: 2.65096e-05	valid_0's binary_logloss: 2.65096e-05
# [166]	valid_0's binary_logloss: 2.52166e-05	valid_0's binary_logloss: 2.52166e-05
# [167]	valid_0's binary_logloss: 2.39867e-05	valid_0's binary_logloss: 2.39867e-05
# [168]	valid_0's binary_logloss: 2.28168e-05	valid_0's binary_logloss: 2.28168e-05
# [169]	valid_0's binary_logloss: 2.1704e-05	valid_0's binary_logloss: 2.1704e-05
# [170]	valid_0's binary_logloss: 2.06454e-05	valid_0's binary_logloss: 2.06454e-05
# [171]	valid_0's binary_logloss: 1.96385e-05	valid_0's binary_logloss: 1.96385e-05
# [172]	valid_0's binary_logloss: 1.86807e-05	valid_0's binary_logloss: 1.86807e-05
# [173]	valid_0's binary_logloss: 1.77696e-05	valid_0's binary_logloss: 1.77696e-05
# [174]	valid_0's binary_logloss: 1.69029e-05	valid_0's binary_logloss: 1.69029e-05
# [175]	valid_0's binary_logloss: 1.60785e-05	valid_0's binary_logloss: 1.60785e-05
# [176]	valid_0's binary_logloss: 1.52943e-05	valid_0's binary_logloss: 1.52943e-05
# [177]	valid_0's binary_logloss: 1.45484e-05	valid_0's binary_logloss: 1.45484e-05
# [178]	valid_0's binary_logloss: 1.38388e-05	valid_0's binary_logloss: 1.38388e-05
# [179]	valid_0's binary_logloss: 1.31639e-05	valid_0's binary_logloss: 1.31639e-05
# [180]	valid_0's binary_logloss: 1.25218e-05	valid_0's binary_logloss: 1.25218e-05
# [181]	valid_0's binary_logloss: 1.19111e-05	valid_0's binary_logloss: 1.19111e-05
# [182]	valid_0's binary_logloss: 1.13302e-05	valid_0's binary_logloss: 1.13302e-05
# [183]	valid_0's binary_logloss: 1.07776e-05	valid_0's binary_logloss: 1.07776e-05
# [184]	valid_0's binary_logloss: 1.0252e-05	valid_0's binary_logloss: 1.0252e-05
# [185]	valid_0's binary_logloss: 9.75196e-06	valid_0's binary_logloss: 9.75196e-06
# [186]	valid_0's binary_logloss: 9.27634e-06	valid_0's binary_logloss: 9.27634e-06
# [187]	valid_0's binary_logloss: 8.82392e-06	valid_0's binary_logloss: 8.82392e-06
# [188]	valid_0's binary_logloss: 8.39356e-06	valid_0's binary_logloss: 8.39356e-06
# [189]	valid_0's binary_logloss: 7.9842e-06	valid_0's binary_logloss: 7.9842e-06
# [190]	valid_0's binary_logloss: 7.5948e-06	valid_0's binary_logloss: 7.5948e-06
# [191]	valid_0's binary_logloss: 7.22439e-06	valid_0's binary_logloss: 7.22439e-06
# [192]	valid_0's binary_logloss: 6.87205e-06	valid_0's binary_logloss: 6.87205e-06
# [193]	valid_0's binary_logloss: 6.53689e-06	valid_0's binary_logloss: 6.53689e-06
# [194]	valid_0's binary_logloss: 6.21807e-06	valid_0's binary_logloss: 6.21807e-06
# [195]	valid_0's binary_logloss: 5.91481e-06	valid_0's binary_logloss: 5.91481e-06
# [196]	valid_0's binary_logloss: 5.62634e-06	valid_0's binary_logloss: 5.62634e-06
# [197]	valid_0's binary_logloss: 5.35194e-06	valid_0's binary_logloss: 5.35194e-06
# [198]	valid_0's binary_logloss: 5.09092e-06	valid_0's binary_logloss: 5.09092e-06
# [199]	valid_0's binary_logloss: 4.84263e-06	valid_0's binary_logloss: 4.84263e-06
# [200]	valid_0's binary_logloss: 4.60645e-06	valid_0's binary_logloss: 4.60645e-06
# [201]	valid_0's binary_logloss: 4.38178e-06	valid_0's binary_logloss: 4.38178e-06
# [202]	valid_0's binary_logloss: 4.16808e-06	valid_0's binary_logloss: 4.16808e-06
# [203]	valid_0's binary_logloss: 3.9648e-06	valid_0's binary_logloss: 3.9648e-06
# [204]	valid_0's binary_logloss: 3.77143e-06	valid_0's binary_logloss: 3.77143e-06
# [205]	valid_0's binary_logloss: 3.5875e-06	valid_0's binary_logloss: 3.5875e-06
# [206]	valid_0's binary_logloss: 3.41253e-06	valid_0's binary_logloss: 3.41253e-06
# [207]	valid_0's binary_logloss: 3.2461e-06	valid_0's binary_logloss: 3.2461e-06
# [208]	valid_0's binary_logloss: 3.08778e-06	valid_0's binary_logloss: 3.08778e-06
# [209]	valid_0's binary_logloss: 2.93719e-06	valid_0's binary_logloss: 2.93719e-06
# [210]	valid_0's binary_logloss: 2.79394e-06	valid_0's binary_logloss: 2.79394e-06
# [211]	valid_0's binary_logloss: 2.65768e-06	valid_0's binary_logloss: 2.65768e-06
# [212]	valid_0's binary_logloss: 2.52806e-06	valid_0's binary_logloss: 2.52806e-06
# [213]	valid_0's binary_logloss: 2.40476e-06	valid_0's binary_logloss: 2.40476e-06
# [214]	valid_0's binary_logloss: 2.28748e-06	valid_0's binary_logloss: 2.28748e-06
# [215]	valid_0's binary_logloss: 2.17592e-06	valid_0's binary_logloss: 2.17592e-06
# [216]	valid_0's binary_logloss: 2.0698e-06	valid_0's binary_logloss: 2.0698e-06
# [217]	valid_0's binary_logloss: 1.96885e-06	valid_0's binary_logloss: 1.96885e-06
# [218]	valid_0's binary_logloss: 1.87283e-06	valid_0's binary_logloss: 1.87283e-06
# [219]	valid_0's binary_logloss: 1.78149e-06	valid_0's binary_logloss: 1.78149e-06
# [220]	valid_0's binary_logloss: 1.69461e-06	valid_0's binary_logloss: 1.69461e-06
# [221]	valid_0's binary_logloss: 1.61196e-06	valid_0's binary_logloss: 1.61196e-06
# [222]	valid_0's binary_logloss: 1.53334e-06	valid_0's binary_logloss: 1.53334e-06
# [223]	valid_0's binary_logloss: 1.45856e-06	valid_0's binary_logloss: 1.45856e-06
# [224]	valid_0's binary_logloss: 1.38742e-06	valid_0's binary_logloss: 1.38742e-06
# [225]	valid_0's binary_logloss: 1.31976e-06	valid_0's binary_logloss: 1.31976e-06
# [226]	valid_0's binary_logloss: 1.25539e-06	valid_0's binary_logloss: 1.25539e-06
# [227]	valid_0's binary_logloss: 1.19417e-06	valid_0's binary_logloss: 1.19417e-06
# [228]	valid_0's binary_logloss: 1.13593e-06	valid_0's binary_logloss: 1.13593e-06
# [229]	valid_0's binary_logloss: 1.08053e-06	valid_0's binary_logloss: 1.08053e-06
# [230]	valid_0's binary_logloss: 1.02783e-06	valid_0's binary_logloss: 1.02783e-06
# [231]	valid_0's binary_logloss: 9.77701e-07	valid_0's binary_logloss: 9.77701e-07
# [232]	valid_0's binary_logloss: 9.30018e-07	valid_0's binary_logloss: 9.30018e-07
# [233]	valid_0's binary_logloss: 8.8466e-07	valid_0's binary_logloss: 8.8466e-07
# [234]	valid_0's binary_logloss: 8.41515e-07	valid_0's binary_logloss: 8.41515e-07
# [235]	valid_0's binary_logloss: 8.00473e-07	valid_0's binary_logloss: 8.00473e-07
# [236]	valid_0's binary_logloss: 7.61434e-07	valid_0's binary_logloss: 7.61434e-07
# [237]	valid_0's binary_logloss: 7.24298e-07	valid_0's binary_logloss: 7.24298e-07
# [238]	valid_0's binary_logloss: 6.88974e-07	valid_0's binary_logloss: 6.88974e-07
# [239]	valid_0's binary_logloss: 6.55372e-07	valid_0's binary_logloss: 6.55372e-07
# [240]	valid_0's binary_logloss: 6.23409e-07	valid_0's binary_logloss: 6.23409e-07
# [241]	valid_0's binary_logloss: 5.93005e-07	valid_0's binary_logloss: 5.93005e-07
# [242]	valid_0's binary_logloss: 5.64084e-07	valid_0's binary_logloss: 5.64084e-07
# [243]	valid_0's binary_logloss: 5.36573e-07	valid_0's binary_logloss: 5.36573e-07
# [244]	valid_0's binary_logloss: 5.10404e-07	valid_0's binary_logloss: 5.10404e-07
# [245]	valid_0's binary_logloss: 4.85511e-07	valid_0's binary_logloss: 4.85511e-07
# [246]	valid_0's binary_logloss: 4.61833e-07	valid_0's binary_logloss: 4.61833e-07
# [247]	valid_0's binary_logloss: 4.39309e-07	valid_0's binary_logloss: 4.39309e-07
# [248]	valid_0's binary_logloss: 4.17883e-07	valid_0's binary_logloss: 4.17883e-07
# [249]	valid_0's binary_logloss: 3.97503e-07	valid_0's binary_logloss: 3.97503e-07
# [250]	valid_0's binary_logloss: 3.78116e-07	valid_0's binary_logloss: 3.78116e-07
# [251]	valid_0's binary_logloss: 3.59675e-07	valid_0's binary_logloss: 3.59675e-07
# [252]	valid_0's binary_logloss: 3.42134e-07	valid_0's binary_logloss: 3.42134e-07
# [253]	valid_0's binary_logloss: 3.25448e-07	valid_0's binary_logloss: 3.25448e-07
# [254]	valid_0's binary_logloss: 3.09576e-07	valid_0's binary_logloss: 3.09576e-07
# [255]	valid_0's binary_logloss: 2.94477e-07	valid_0's binary_logloss: 2.94477e-07
# [256]	valid_0's binary_logloss: 2.80116e-07	valid_0's binary_logloss: 2.80116e-07
# [257]	valid_0's binary_logloss: 2.66454e-07	valid_0's binary_logloss: 2.66454e-07
# [258]	valid_0's binary_logloss: 2.53459e-07	valid_0's binary_logloss: 2.53459e-07
# [259]	valid_0's binary_logloss: 2.41098e-07	valid_0's binary_logloss: 2.41098e-07
# [260]	valid_0's binary_logloss: 2.29339e-07	valid_0's binary_logloss: 2.29339e-07
# [261]	valid_0's binary_logloss: 2.18154e-07	valid_0's binary_logloss: 2.18154e-07
# [262]	valid_0's binary_logloss: 2.07515e-07	valid_0's binary_logloss: 2.07515e-07
# [263]	valid_0's binary_logloss: 1.97394e-07	valid_0's binary_logloss: 1.97394e-07
# [264]	valid_0's binary_logloss: 1.87767e-07	valid_0's binary_logloss: 1.87767e-07
# [265]	valid_0's binary_logloss: 1.78609e-07	valid_0's binary_logloss: 1.78609e-07
# [266]	valid_0's binary_logloss: 1.69899e-07	valid_0's binary_logloss: 1.69899e-07
# [267]	valid_0's binary_logloss: 1.61613e-07	valid_0's binary_logloss: 1.61613e-07
# [268]	valid_0's binary_logloss: 1.53731e-07	valid_0's binary_logloss: 1.53731e-07
# [269]	valid_0's binary_logloss: 1.46233e-07	valid_0's binary_logloss: 1.46233e-07
# [270]	valid_0's binary_logloss: 1.39101e-07	valid_0's binary_logloss: 1.39101e-07
# [271]	valid_0's binary_logloss: 1.32317e-07	valid_0's binary_logloss: 1.32317e-07
# [272]	valid_0's binary_logloss: 1.25864e-07	valid_0's binary_logloss: 1.25864e-07
# [273]	valid_0's binary_logloss: 1.19726e-07	valid_0's binary_logloss: 1.19726e-07
# [274]	valid_0's binary_logloss: 1.13886e-07	valid_0's binary_logloss: 1.13886e-07
# [275]	valid_0's binary_logloss: 1.08332e-07	valid_0's binary_logloss: 1.08332e-07
# [276]	valid_0's binary_logloss: 1.03049e-07	valid_0's binary_logloss: 1.03049e-07
# [277]	valid_0's binary_logloss: 9.80229e-08	valid_0's binary_logloss: 9.80229e-08
# [278]	valid_0's binary_logloss: 9.32423e-08	valid_0's binary_logloss: 9.32423e-08
# [279]	valid_0's binary_logloss: 8.86948e-08	valid_0's binary_logloss: 8.86948e-08
# [280]	valid_0's binary_logloss: 8.43691e-08	valid_0's binary_logloss: 8.43691e-08
# [281]	valid_0's binary_logloss: 8.02544e-08	valid_0's binary_logloss: 8.02544e-08
# [282]	valid_0's binary_logloss: 7.63403e-08	valid_0's binary_logloss: 7.63403e-08
# [283]	valid_0's binary_logloss: 7.26172e-08	valid_0's binary_logloss: 7.26172e-08
# [284]	valid_0's binary_logloss: 6.90756e-08	valid_0's binary_logloss: 6.90756e-08
# [285]	valid_0's binary_logloss: 6.57067e-08	valid_0's binary_logloss: 6.57067e-08
# [286]	valid_0's binary_logloss: 6.25022e-08	valid_0's binary_logloss: 6.25022e-08
# [287]	valid_0's binary_logloss: 5.94539e-08	valid_0's binary_logloss: 5.94539e-08
# [288]	valid_0's binary_logloss: 5.65543e-08	valid_0's binary_logloss: 5.65543e-08
# [289]	valid_0's binary_logloss: 5.37961e-08	valid_0's binary_logloss: 5.37961e-08
# [290]	valid_0's binary_logloss: 5.11725e-08	valid_0's binary_logloss: 5.11725e-08
# [291]	valid_0's binary_logloss: 4.86767e-08	valid_0's binary_logloss: 4.86767e-08
# [292]	valid_0's binary_logloss: 4.63028e-08	valid_0's binary_logloss: 4.63028e-08
# [293]	valid_0's binary_logloss: 4.40445e-08	valid_0's binary_logloss: 4.40445e-08
# [294]	valid_0's binary_logloss: 4.18965e-08	valid_0's binary_logloss: 4.18965e-08
# [295]	valid_0's binary_logloss: 3.98532e-08	valid_0's binary_logloss: 3.98532e-08
# [296]	valid_0's binary_logloss: 3.79095e-08	valid_0's binary_logloss: 3.79095e-08
# [297]	valid_0's binary_logloss: 3.60606e-08	valid_0's binary_logloss: 3.60606e-08
# [298]	valid_0's binary_logloss: 3.43019e-08	valid_0's binary_logloss: 3.43019e-08
# [299]	valid_0's binary_logloss: 3.2629e-08	valid_0's binary_logloss: 3.2629e-08
# [300]	valid_0's binary_logloss: 3.10377e-08	valid_0's binary_logloss: 3.10377e-08
# Did not meet early stopping. Best iteration is:
# [300]	valid_0's binary_logloss: 3.10377e-08	valid_0's binary_logloss: 3.10377e-08

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score, roc_auc_score

def get_clf_eval(y_test, pred):
    confusion = confusion_matrix( y_test, pred)
    accuracy = accuracy_score(y_test , pred)
    precision = precision_score(y_test , pred)
    recall = recall_score(y_test , pred)
    f1 = f1_score(y_test,pred)

    print('오차 행렬')
    print(confusion)
    # ROC-AUC print 추가
    print('정확도: {0:.2f}, 정밀도: {1:.2f}, 재현율: {2:.2f},\
    F1: {3:.2f}'.format(accuracy, precision, recall, f1))

# %% [markdown]
# ## Socre

# %%
get_clf_eval(y_test, preds)
# Out:
# 오차 행렬
# [[70564     0]
#  [    0  4109]]
# 정확도: 1.00, 정밀도: 1.00, 재현율: 1.00,    F1: 1.00

# %% [markdown]
# - 일단 잘 맞춘다. 사실상 자동으로 이상치 탐색해주는 모델
#
#
# - 사실상 스머프는 잡기 힘들다. 그냥 잘하는데 못올라가는 경우도 있으니, 이건 운영적인 부분으로 잡아야한다 . (부계정을 못만들게 한다던가)

# %%
sns.relplot(x="nbpicks", y="hax", hue="hax", style= "hax" , data=df_gb)

# %% [markdown]
# - 이상치 발견된 데이터는 게임을 오래 못하는것을 볼 수 있다.
#
# - 즉 핵 유저는 정지를 당해서 플레이가 중단되거나, 양학을 하는 유저는 랭크가 올라 양학을 하지 못하는것으로 보인다.
#
# - 불법프로그램을 판별할때 picks도 사용 가능한것으로 보임
